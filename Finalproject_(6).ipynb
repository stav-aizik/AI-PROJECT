# %% [markdown]
# <a href="https://colab.research.google.com/github/stav-aizik/AI-PROJECT/blob/main/Finalproject_(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import libraries and download TSLA data

# %%
#import libraries
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
import tensorflow as tf
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN , Dense , LSTM ,Dropout , GRU ,Flatten ,Bidirectional , Embedding, GlobalAveragePooling1D
from tensorflow.keras.callbacks import EarlyStopping , ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop,SGD
from statsmodels.tsa.seasonal import seasonal_decompose
import re
from collections import Counter
from tensorflow.keras.layers import BatchNormalization
#tokenizer
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import string
from textblob import TextBlob, Word
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
#download data(tesla) from yahoo Finance
tsla = yf.download("TSLA",start="2021-09-01",end="2022-09-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tsla.columns = [col[0] for col in tsla.columns]

# %%
tsla
# Out:
#                  Close        High         Low        Open    Volume
# Date
# 2021-09-01  244.696671  247.330002  243.756668  244.693329  39612900
# 2021-09-02  244.130005  246.990005  243.513336  244.833328  38331900
# 2021-09-03  244.523331  244.666672  241.399994  244.083328  45738300
# 2021-09-07  250.973328  253.399994  246.419998  246.666672  60119400
# 2021-09-08  251.289993  254.816666  246.923340  253.860001  56379000
# ...                ...         ...         ...         ...       ...
# 2022-08-25  296.070007  302.959991  291.600006  302.359985  53230000
# 2022-08-26  288.089996  302.000000  287.470001  297.429993  57163900
# 2022-08-29  284.820007  287.739990  280.700012  282.829987  41864700
# 2022-08-30  277.700012  288.480011  272.649994  287.869995  50541800
# 2022-08-31  275.609985  281.250000  271.809998  280.619995  52107300
#
# [252 rows x 5 columns]

# %%
tsla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2021-09-01 to 2022-08-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   252 non-null    float64
#  1   High    252 non-null    float64
#  2   Low     252 non-null    float64
#  3   Open    252 non-null    float64
#  4   Volume  252 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.8 KB

# %% [markdown]
# #Downlowd elon_musk_tweets Dataset

# %% [markdown]
# משיכה של הקובץ :

# %%
##download elon musk tweets dataset
#https://drive.google.com/file/d/1VO5RyMP4pm5vIbc3w4VPdX8HzPi_MyCC/view?usp=sharing
# !gdown --fuzzy "https://drive.google.com/file/d/1VO5RyMP4pm5vIbc3w4VPdX8HzPi_MyCC/view?usp=sharing" -O elon_musk_tweets.zip
#unzip
# !unzip elon_musk_tweets.zip -d elon_musk_tweets
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VO5RyMP4pm5vIbc3w4VPdX8HzPi_MyCC
# To: /content/elon_musk_tweets.zip
# 100% 870k/870k [00:00<00:00, 69.5MB/s]
# Archive:  elon_musk_tweets.zip
# replace elon_musk_tweets/elonmusk.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: elon_musk_tweets/elonmusk.csv

# %%
#read csv elon musk tweets
df=pd.read_csv("/content/elon_musk_tweets/elonmusk.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17437 entries, 0 to 17436
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date Created     17437 non-null  object
#  1   Number of Likes  17437 non-null  int64
#  2   Source of Tweet  17437 non-null  object
#  3   Tweets           17437 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 545.0+ KB

# %%
df
# Out:
#                     Date Created  Number of Likes     Source of Tweet  \
# 0      2022-09-12 05:44:11+00:00             1524  Twitter for iPhone
# 1      2022-09-12 05:43:02+00:00            19631  Twitter for iPhone
# 2      2022-09-12 04:19:57+00:00             9221  Twitter for iPhone
# 3      2022-09-12 03:25:03+00:00              944  Twitter for iPhone
# 4      2022-09-12 01:48:49+00:00             3710  Twitter for iPhone
# ...                          ...              ...                 ...
# 17432  2011-12-03 08:22:07+00:00               51  Twitter for iPhone
# 17433  2011-12-03 08:20:28+00:00               53  Twitter for iPhone
# 17434  2011-12-01 10:29:04+00:00               75  Twitter Web Client
# 17435  2011-12-01 09:55:11+00:00              189  Twitter Web Client
# 17436  2010-06-04 18:31:57+00:00             6042  Twitter Web Client
#
#                                                   Tweets
# 0      @teslaownersSV @cb_doge @Tesla @mayemusk I gue...
# 1      @cb_doge @Tesla @mayemusk Still doing same thi...
# 2      Looks good to roll out to all Tesla owners wit...
# 3      @Tesla__Mania @WholeMarsBlog That is probably ...
# 4      @WholeMarsBlog Real-world validation &amp; bil...
# ...                                                  ...
# 17432                  That was a total non sequitur btw
# 17433  Great Voltaire quote, arguably better than Twa...
# 17434  I made the volume on the Model S http://t.co/w...
# 17435  Went to Iceland on Sat to ride bumper cars on ...
# 17436  Please ignore prior tweets, as that was someon...
#
# [17437 rows x 4 columns]

# %% [markdown]
# Creates a new DataFrame elon_df with just the tweet text and creation date.

# %%
elon_df = df[['Date Created', 'Tweets']].copy()

# %%
#create a Date column - datetime type
elon_df['Date'] = pd.to_datetime(df['Date Created'])

# %%
#Selection of a relevant date
start_date = pd.to_datetime('2021-09-01').tz_localize('UTC')
end_date = pd.to_datetime('2022-09-01').tz_localize('UTC')

elon_df = elon_df[(elon_df['Date'] >= start_date) & (elon_df['Date'] < end_date)]

# %%
elon_df
# Out:
#                    Date Created  \
# 80    2022-08-31 15:39:27+00:00
# 81    2022-08-31 15:16:57+00:00
# 82    2022-08-31 15:13:23+00:00
# 83    2022-08-31 15:06:53+00:00
# 84    2022-08-30 22:52:58+00:00
# ...                         ...
# 3737  2021-09-01 16:46:52+00:00
# 3738  2021-09-01 16:42:32+00:00
# 3739  2021-09-01 16:21:41+00:00
# 3740  2021-09-01 16:13:33+00:00
# 3741  2021-09-01 02:44:40+00:00
#
#                                                  Tweets  \
# 80    @ChrisZheng001 I intend to do so as soon as po...
# 81                                     @teslaownersSV 🤣
# 82    @SciGuySpace Yeah, aiming for up to 100 flight...
# 83                          Now launching every ~5 days
# 84    @WholeMarsBlog @jonbbc @aelluswamy 10.69.2 goe...
# ...                                                 ...
# 3737  @DJSnM @thesheetztweetz @johnkrausphotos @Lyla...
# 3738  @DJSnM @thesheetztweetz @johnkrausphotos @Lyla...
# 3739  @thesheetztweetz Filing legal actions against ...
# 3740  @SciGuySpace He should consider spending some ...
# 3741    @MarcusHouse @BocaChicaGal @NASASpaceflight Yup
#
#                           Date
# 80   2022-08-31 15:39:27+00:00
# 81   2022-08-31 15:16:57+00:00
# 82   2022-08-31 15:13:23+00:00
# 83   2022-08-31 15:06:53+00:00
# 84   2022-08-30 22:52:58+00:00
# ...                        ...
# 3737 2021-09-01 16:46:52+00:00
# 3738 2021-09-01 16:42:32+00:00
# 3739 2021-09-01 16:21:41+00:00
# 3740 2021-09-01 16:13:33+00:00
# 3741 2021-09-01 02:44:40+00:00
#
# [3662 rows x 3 columns]

# %% [markdown]
# #Statistical Data - TSLA

# %%
#describe
tsla.describe()
# Out:
#             Close        High         Low        Open        Volume
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   296.773651  304.358889  289.330211  297.211839  8.012612e+07
# std     47.546290   48.915248   46.225322   47.989156  2.608064e+07
# min    209.386673  217.973328  206.856674  207.949997  3.504270e+07
# 25%    255.262497  261.730003  249.826668  255.566669  6.192960e+07
# 50%    292.128342  301.179993  285.813339  295.166672  7.710210e+07
# 75%    336.472504  344.957512  327.908340  335.700005  9.351338e+07
# max    409.970001  414.496674  405.666656  411.470001  1.885563e+08

# %% [markdown]
# statistical by months:

# %%
tsla['month']=tsla.index.to_period('M')

# %%
#GroupBy Monthe
group_month = tsla.groupby('month')

# %%
group_month.mean()
# Out:
#               Close        High         Low        Open        Volume
# month
# 2021-09  251.317463  253.858095  247.543493  250.604284  5.573876e+07
# 2021-10  292.783017  296.909206  287.247936  289.953491  7.556209e+07
# 2021-11  373.554125  382.863017  362.036666  372.588890  9.273021e+07
# 2021-12  339.629999  348.253938  330.886665  341.477726  6.955308e+07
# 2022-01  336.722830  349.012334  326.520500  339.770000  9.580032e+07
# 2022-02  292.961577  301.286843  284.898768  292.789474  7.321719e+07
# 2022-03  304.793186  311.332608  296.599713  303.253333  7.518578e+07
# 2022-04  332.462503  344.035336  325.974168  337.054169  7.604799e+07
# 2022-05  255.223333  264.414288  246.076190  256.985554  9.277246e+07
# 2022-06  234.025873  241.544444  228.351111  234.472539  9.577276e+07
# 2022-07  251.394666  255.841666  243.754666  248.886668  8.724420e+07
# 2022-08  294.869857  301.852028  290.238551  297.223042  7.370710e+07

# %%
group_month.describe()
# Out:
#         Close                                                             \
#         count        mean        std         min         25%         50%
# month
# 2021-09  21.0  251.317463   5.874000  243.389999  246.460007  251.213333
# 2021-10  21.0  292.783017  36.500997  258.406677  263.980011  281.010010
# 2021-11  21.0  373.554125  22.071917  337.796661  355.983337  372.000000
# 2021-12  22.0  339.629999  20.612209  299.980011  322.934990  338.666672
# 2022-01  20.0  336.722830  31.675523  276.366669  312.412498  342.911667
# 2022-02  19.0  292.961577  16.457416  254.679993  286.163330  297.046661
# 2022-03  23.0  304.793186  36.075913  255.456665  279.431656  290.533325
# 2022-04  20.0  332.462503  24.950996  290.253326  325.627502  334.889999
# 2022-05  21.0  255.223333  29.855613  209.386673  236.473328  252.753326
# 2022-06  21.0  234.025873  11.247435  213.100006  228.490005  235.070007
# 2022-07  20.0  251.394666  19.678442  227.263336  236.365829  245.036667
# 2022-08  23.0  294.869857   9.581290  275.609985  288.130005  296.453339
#
#                                  High              ...        Open  \
#                 75%         max count        mean  ...         75%
# month                                              ...
# 2021-09  253.163330  263.786682  21.0  253.858095  ...  253.199997
# 2021-10  303.226654  371.333344  21.0  296.909206  ...  298.500000
# 2021-11  387.646667  409.970001  21.0  382.863017  ...  387.443329
# 2021-12  356.665001  365.000000  22.0  348.253938  ...  357.870842
# 2022-01  354.824989  399.926666  20.0  349.012334  ...  359.743332
# 2022-02  307.404999  310.666656  19.0  301.286843  ...  304.551666
# 2022-03  334.958344  366.523346  23.0  311.332608  ...  331.323334
# 2022-04  344.184174  381.816681  20.0  344.035336  ...  352.553329
# 2022-05  266.679993  317.540009  21.0  264.414288  ...  278.816681
# 2022-06  239.706665  258.333344  21.0  241.544444  ...  244.156662
# 2022-07  269.251656  297.149994  20.0  255.841666  ...  264.485832
# 2022-08  301.728333  309.320007  23.0  301.852028  ...  302.514999
#
#                     Volume                                          \
#                 max  count          mean           std         min
# month
# 2021-09  262.399994   21.0  5.573876e+07  1.501086e+07  35842500.0
# 2021-10  360.619995   21.0  7.556209e+07  4.273815e+07  36741600.0
# 2021-11  411.470001   21.0  9.273021e+07  3.539410e+07  35042700.0
# 2021-12  386.899994   22.0  6.955308e+07  1.685216e+07  40733700.0
# 2022-01  396.516663   20.0  9.580032e+07  2.463356e+07  66063300.0
# 2022-02  311.736664   19.0  7.321719e+07  2.039672e+07  50729100.0
# 2022-03  369.329987   23.0  7.518578e+07  1.744512e+07  48992700.0
# 2022-04  378.766663   20.0  7.604799e+07  2.373524e+07  49847700.0
# 2022-05  313.006653   21.0  9.277246e+07  1.905685e+07  63709500.0
# 2022-06  251.720001   21.0  9.577276e+07  1.320167e+07  72808500.0
# 2022-07  280.700012   20.0  8.724420e+07  1.724209e+07  64073400.0
# 2022-08  311.666656   23.0  7.370710e+07  2.127902e+07  41864700.0
#
#
#                 25%         50%          75%          max
# month
# 2021-09  45378900.0  53868000.0   64119000.0   84612600.0
# 2021-10  50215800.0  57587400.0   89755200.0  188556300.0
# 2021-11  67189800.0  81276000.0  104326800.0  177317400.0
# 2021-12  57219675.0  70976100.0   80896125.0  100437300.0
# 2022-01  78950475.0  91075800.0  104057550.0  151565700.0
# 2022-02  59140350.0  68501700.0   79250700.0  135322200.0
# 2022-03  64307250.0  71152200.0   81190350.0  120676200.0
# 2022-04  57597000.0  70203900.0   83560200.0  136133700.0
# 2022-05  84401700.0  89295000.0   92519100.0  144973200.0
# 2022-06  89178300.0  95770800.0  102767400.0  122793000.0
# 2022-07  77533125.0  84652050.0   95973375.0  142032300.0
# 2022-08  56503550.0  70155000.0   88747800.0  117042900.0
#
# [12 rows x 40 columns]

# %%
# just the Close price statistics from the grouped monthly data
Close = group_month.describe()['Close'][['max','min','mean']]

# %%
#close describe
plt.title('Close describe')
sns.barplot(x='month',y='max' , data = Close , color= 'teal',label = 'max')
sns.barplot(x='month',y='mean' , data = Close, color= 'mediumturquoise',label = 'mean')
sns.barplot(x='month',y='min' , data = Close , color= 'skyblue',label = 'min')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Volume = group_month.describe()['Volume'][['max','min','mean']]

# %%
#Volume describe
plt.title('Volume describe')
sns.barplot(x='month',y='max' , data = Volume , color= 'teal',label = 'max')
sns.barplot(x='month',y='mean' , data = Volume, color= 'mediumturquoise',label = 'mean')
sns.barplot(x='month',y='min' , data = Volume , color= 'skyblue',label = 'min')
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# statistical by day of week:

# %%
tsla['day of week']=tsla.index.day_of_week

# %%
group_day=tsla.groupby('day of week')

# %%
tsla.head(1)
# Out:
#                  Close        High         Low        Open    Volume    month  \
# Date
# 2021-09-01  244.696671  247.330002  243.756668  244.693329  39612900  2021-09
#
#             day of week
# Date
# 2021-09-01            2

# %%
group_day.describe()
# Out:
#             Close                                                             \
#             count        mean        std         min         25%         50%
# day of week
# 0            46.0  302.160871  50.483449  215.736664  262.724167  298.628342
# 1            52.0  296.813972  48.088550  209.386673  257.612488  294.296677
# 2            53.0  297.298490  48.358046  219.600006  251.289993  294.356659
# 3            51.0  294.653399  46.424061  213.100006  255.331673  291.093323
# 4            50.0  293.381800  45.910999  216.759995  256.930000  288.130005
#
#                                      High              ...        Open  \
#                     75%         max count        mean  ...         75%
# day of week                                            ...
# 0            335.943336  402.863342  46.0  309.016450  ...  332.419174
# 1            339.899155  390.666656  52.0  305.298782  ...  334.582504
# 2            336.290009  404.619995  53.0  304.294717  ...  336.803345
# 3            335.430008  409.970001  51.0  303.314902  ...  336.576660
# 4            336.414169  407.363342  50.0  300.229334  ...  336.187500
#
#                         Volume                                          \
#                     max  count          mean           std         min
# day of week
# 0            387.443329   46.0  8.644927e+07  2.850052e+07  41864700.0
# 1            396.516663   52.0  8.194073e+07  2.831693e+07  48992100.0
# 2            392.443329   53.0  7.621656e+07  2.228186e+07  39612900.0
# 3            411.470001   51.0  7.868475e+07  2.771287e+07  35842500.0
# 4            409.333344   50.0  7.803595e+07  2.300007e+07  35042700.0
#
#
#                     25%         50%         75%          max
# day of week
# 0            69429600.0  83371050.0  99164850.0  188556300.0
# 1            65478225.0  77885700.0  88375425.0  187245000.0
# 2            57259800.0  76210500.0  92139300.0  128408100.0
# 3            58535400.0  76192200.0  93958800.0  147109500.0
# 4            62553450.0  74042850.0  92561850.0  144973200.0
#
# [5 rows x 40 columns]

# %%
Close_day = group_day.describe()['Close'][['max','min','mean']]

# %%
#Close day - Max,Min,Mean
Close_day
# Out:
#                     max         min        mean
# day of week
# 0            402.863342  215.736664  302.160871
# 1            390.666656  209.386673  296.813972
# 2            404.619995  219.600006  297.298490
# 3            409.970001  213.100006  294.653399
# 4            407.363342  216.759995  293.381800

# %%
days = Close_day.index
max_values = Close_day['max']
mean_values = Close_day['mean']
min_values = Close_day['min']

x = np.arange(len(days))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width, max_values, width, label='max', color='teal')
plt.bar(x, mean_values, width, label='mean', color='mediumturquoise')
plt.bar(x + width, min_values, width, label='min', color='skyblue')

plt.title('Close Price Statistics - Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Close Price')
plt.legend(title='Statistic')

plt.tight_layout()
plt.show()

# %% [markdown]
# heatmap:

# %%
#correlation matrix
correlation_matrix = tsla[['Open', 'High', 'Low', 'Close', 'Volume']].corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', linewidths=0.5, fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.regplot(x='Close' , y='High' , data = tsla)
# Out:
# <Axes: xlabel='Close', ylabel='High'>

# %%
sns.regplot(x='Close' , y='Open' , data = tsla)
# Out:
# <Axes: xlabel='Close', ylabel='Open'>

# %%
# Adds a 'Quarter' column
tsla['Quarter'] = tsla.index.to_period('Q')

# Takes the first row of each quarter group
quarter_start = tsla.groupby('Quarter').head(1)

quarter_start[['Open', 'High', 'Low', 'Close', 'Volume']]
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2021-09-01  244.693329  247.330002  243.756668  244.696671   39612900
# 2021-10-01  259.466675  260.260010  254.529999  258.406677   51094200
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  103931400
# 2022-04-01  360.383331  364.916656  355.546661  361.529999   54263100
# 2022-07-01  227.000000  230.229996  222.119995  227.263336   74460300

# %%
quarter_start
# Out:
#                  Close        High         Low        Open     Volume  \
# Date
# 2021-09-01  244.696671  247.330002  243.756668  244.693329   39612900
# 2021-10-01  258.406677  260.260010  254.529999  259.466675   51094200
# 2022-01-03  399.926666  400.356659  378.679993  382.583344  103931400
# 2022-04-01  361.529999  364.916656  355.546661  360.383331   54263100
# 2022-07-01  227.263336  230.229996  222.119995  227.000000   74460300
#
#               month  day of week Quarter
# Date
# 2021-09-01  2021-09            2  2021Q3
# 2021-10-01  2021-10            4  2021Q4
# 2022-01-03  2022-01            0  2022Q1
# 2022-04-01  2022-04            4  2022Q2
# 2022-07-01  2022-07            4  2022Q3

# %%
volum_quarter = quarter_start.Volume

# %%
#pie chart of quarterly trading volumes
plt.title('Volume Quarter', fontsize=14)
plt.pie(volum_quarter,labels = volum_quarter.index,
        wedgeprops = {'edgecolor' :'k',
                      'linewidth': 0.7} ,
        shadow = True ,
        colors = ['teal', 'mediumturquoise', 'skyblue'],
       autopct='%1.1f%%',
        )

plt.show()

# %%
max_date=tsla['Close'].idxmax()
min_date=tsla['Close'].idxmin()
highlight_dates = [tsla['Close'].idxmax(),tsla['Close'].idxmin()]
highlight_values = tsla.loc[highlight_dates, 'Close']

# %%
#
plt.subplots(figsize=(20,15))
plt.title('max&min close value',fontsize=24)
sns.lineplot(x='Date',y='Close' , data = tsla , linewidth=3, color= 'teal',label = 'Close')
plt.xlabel('Date',fontsize=14)
plt.ylabel('close value',fontsize=14)
plt.xticks(rotation=45)

plt.scatter(highlight_dates, highlight_values, color='blue', s=200,
            label=f'Highlighted Points\n(max = {max_date.date()})\n(min = {min_date.date()})')
plt.legend()
plt.show()

# %%
group_day.describe()['Close'][['mean']]
# Out:
#                    mean
# day of week
# 0            302.160871
# 1            296.813972
# 2            297.298490
# 3            294.653399
# 4            293.381800

# %%
close_d_mean = group_day.describe()['Close'][['mean']]

# %%
plt.subplots(figsize=(20,15))
plt.title('day average - close price',fontsize=24)
sns.barplot(x='day of week',y='mean' , data = close_d_mean , color= 'teal',label = 'mean')
plt.ylim(275,315)
plt.xlabel('day',fontsize=14)
plt.ylabel('Close-mean',fontsize=14)
plt.xticks(rotation=0)
plt.show()

# %%
close_m_mean = group_month.describe()['Close'][['mean']]

# %%
plt.subplots(figsize=(20,15))
plt.title('mounth average - close price',fontsize=24)
sns.barplot(x='month',y='mean' , data = close_m_mean , color= 'teal',label = 'mean')
plt.ylim(220,380)
plt.xlabel('mounth',fontsize=14)
plt.ylabel('Close-mean',fontsize=14)
plt.xticks(rotation=45)
plt.show()

# %%
#Boxplot of Close prices – shows median, quartiles, and outliers
plt.figure(figsize=(10, 5))
sns.boxplot(x=tsla['Close'])
plt.title("Boxplot of Close Prices")
plt.show()

# %%
# Histogram to visualize distribution of Close prices
tsla['Close'].hist(bins=50,color='cornflowerblue', edgecolor='black', figsize=(10, 5))
plt.title("Histogram of Close Prices")
plt.show()

# %%
Q1 = tsla['Close'].quantile(0.25)
Q3 = tsla['Close'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_iqr = tsla[(tsla['Close'] < lower_bound) | (tsla['Close'] > upper_bound)]
print(outliers_iqr[['Close']])
# Out:
# Empty DataFrame
# Columns: [Close]
# Index: []

# %% [markdown]
# #Pre-processing - TSLA

# %%
#Drops unnecessary columns
tsla.drop(['month','day of week','Quarter'],axis=1,inplace=True)

# %%
pd.concat([tsla["Close"],
           tsla["Close"].shift(-1),
           tsla["Close"].shift(+1)],
          keys = ["Close","tmw", "yesteday"], axis =1).head()
# Out:
#                  Close         tmw    yesteday
# Date
# 2021-09-01  244.696671  244.130005         NaN
# 2021-09-02  244.130005  244.523331  244.696671
# 2021-09-03  244.523331  250.973328  244.130005
# 2021-09-07  250.973328  251.289993  244.523331
# 2021-09-08  251.289993  251.619995  250.973328

# %%
#calculating the daily change
tsla["Change"] = (tsla["Close"].shift(-1)- tsla["Close"])

# %%
#Assigns binary labels
tsla.loc[tsla["Change"] >0, "label"]= 1
#tsla.loc[tsla["Change"] <0, "label"]= -1
tsla.loc[tsla["Change"] <0, "label"]= 0

# %%
tsla
# Out:
#                  Close        High         Low        Open    Volume  \
# Date
# 2021-09-01  244.696671  247.330002  243.756668  244.693329  39612900
# 2021-09-02  244.130005  246.990005  243.513336  244.833328  38331900
# 2021-09-03  244.523331  244.666672  241.399994  244.083328  45738300
# 2021-09-07  250.973328  253.399994  246.419998  246.666672  60119400
# 2021-09-08  251.289993  254.816666  246.923340  253.860001  56379000
# ...                ...         ...         ...         ...       ...
# 2022-08-25  296.070007  302.959991  291.600006  302.359985  53230000
# 2022-08-26  288.089996  302.000000  287.470001  297.429993  57163900
# 2022-08-29  284.820007  287.739990  280.700012  282.829987  41864700
# 2022-08-30  277.700012  288.480011  272.649994  287.869995  50541800
# 2022-08-31  275.609985  281.250000  271.809998  280.619995  52107300
#
#               Change  label
# Date
# 2021-09-01 -0.566666    0.0
# 2021-09-02  0.393326    1.0
# 2021-09-03  6.449997    1.0
# 2021-09-07  0.316666    1.0
# 2021-09-08  0.330002    1.0
# ...              ...    ...
# 2022-08-25 -7.980011    0.0
# 2022-08-26 -3.269989    0.0
# 2022-08-29 -7.119995    0.0
# 2022-08-30 -2.090027    0.0
# 2022-08-31       NaN    NaN
#
# [252 rows x 7 columns]

# %%
tsla = tsla.dropna(subset=['label'])

# %%
#Defining features , target & train , test
split_index = int(len(tsla) * 0.8)
train = tsla.iloc[:split_index]
test = tsla.iloc[split_index:]
features=['Close','High','Low','Open','Volume']
target = 'label'

# %%
#split train & test
X_train=train[features]
X_test=test[features]
y_train=train[target]
y_test=test[target]

# %% [markdown]
# #Classic models

# %%
#scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#Defining models
models = {

    "Logistic Regression": LogisticRegression(max_iter=200, C=0.001, random_state=42,class_weight='balanced'),
    "Random Forest": RandomForestClassifier(n_estimators=200,criterion='gini', max_depth=7, min_samples_leaf=5, random_state=42),
    "Decision Tree": DecisionTreeClassifier(max_depth=6, min_samples_leaf=5, random_state=42),
    "SVM": SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=42),
    "KNN": KNeighborsClassifier(n_neighbors=7),
    "XGBoost": XGBClassifier(n_estimators=100, max_depth=4, learning_rate=0.1, use_label_encoder=False, eval_metric='logloss', random_state=42)
}

# %%
print(tsla['label'].value_counts(normalize=True))
# Out:
# label
# 1.0    0.541833
# 0.0    0.458167
# Name: proportion, dtype: float64

# %%
# Initialize results list
results = []

# Loop over models
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    conf = confusion_matrix(y_test, y_pred)

    # Append to results list
    results.append({
        "Model": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1-score": f1,
        "Confusion Matrix": conf
    })
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [23:21:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
results_df = pd.DataFrame(results).drop(columns=['Confusion Matrix'])
results_df.sort_values(by='F1-score', ascending=False)
# Out:
#                  Model  Accuracy  Precision    Recall  F1-score
# 1        Random Forest  0.568627   0.555556  0.925926  0.694444
# 3                  SVM  0.529412   0.529412  1.000000  0.692308
# 5              XGBoost  0.607843   0.594595  0.814815  0.687500
# 0  Logistic Regression  0.549020   0.543478  0.925926  0.684932
# 2        Decision Tree  0.549020   0.576923  0.555556  0.566038
# 4                  KNN  0.549020   0.576923  0.555556  0.566038

# %%
for result in results:
    plt.figure(figsize=(4,3))
    sns.heatmap(result['Confusion Matrix'], annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix - {result['Model']}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=results_df, x='Model', y='F1-score')
plt.title('F1-score Comparison Between Models')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #LSTM

# %%
Close_prices = tsla[['Close']].values

# %%
split_index = int(len(Close_prices)*0.8)

# %%
train_data = Close_prices[:split_index]
test_data=Close_prices[split_index:]

# %%
#Scaling
scaler = MinMaxScaler(feature_range=(-1, 1))
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.transform(test_data)

# %%
def create_sequences(data,window_size):
  X,y = [],[]
  for i in range(len(data)-window_size):
    X.append(data[i:i+window_size])
    y.append(data[i + window_size])
  return np.array(X) , np.array(y)

# %%
window_size = 12
X_train , y_train = create_sequences(train_scaled,window_size)
X_test,y_test = create_sequences(test_scaled,window_size)

# %%
X_train = X_train.reshape((X_train.shape[0],X_train.shape[1],1))
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
#Model
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(window_size, 1)),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(64),
    Dropout(0.3),
    Dense(1)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss="mae", optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001))

# %%
#i try too
#model.compile(loss="mae", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# %%
#Stop training if no improvement for 10 epochs
#Reduce LR by 0.5 after 5 epochs without improvement
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# %%
history = model.fit(
    X_train,y_train,
    validation_data=(X_test,y_test),
    epochs=100,
    batch_size=16,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.4612 - val_loss: 0.3629 - learning_rate: 0.0010
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3262 - val_loss: 0.3370 - learning_rate: 0.0010
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3226 - val_loss: 0.2903 - learning_rate: 0.0010
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2775 - val_loss: 0.3478 - learning_rate: 0.0010
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2635 - val_loss: 0.2876 - learning_rate: 0.0010
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2200 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1979 - val_loss: 0.2737 - learning_rate: 0.0010
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2252 - val_loss: 0.3101 - learning_rate: 0.0010
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2217 - val_loss: 0.3012 - learning_rate: 0.0010
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1915 - val_loss: 0.2885 - learning_rate: 0.0010
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2072 - val_loss: 0.3239 - learning_rate: 0.0010
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2098 - val_loss: 0.2749 - learning_rate: 0.0010
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1634 - val_loss: 0.2753 - learning_rate: 5.0000e-04
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1622 - val_loss: 0.2656 - learning_rate: 5.0000e-04
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1738 - val_loss: 0.2662 - learning_rate: 5.0000e-04
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1631 - val_loss: 0.3043 - learning_rate: 5.0000e-04
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1767 - val_loss: 0.3051 - learning_rate: 5.0000e-04
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1562 - val_loss: 0.2496 - learning_rate: 5.0000e-04
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2095 - val_loss: 0.2777 - learning_rate: 5.0000e-04
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1615 - val_loss: 0.2875 - learning_rate: 5.0000e-04
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1596 - val_loss: 0.2975 - learning_rate: 5.0000e-04
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1588 - val_loss: 0.2855 - learning_rate: 5.0000e-04
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1436 - val_loss: 0.2756 - learning_rate: 5.0000e-04
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1391 - val_loss: 0.2924 - learning_rate: 2.5000e-04
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1484 - val_loss: 0.2746 - learning_rate: 2.5000e-04
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1560 - val_loss: 0.2580 - learning_rate: 2.5000e-04
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1444 - val_loss: 0.2662 - learning_rate: 2.5000e-04
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1496 - val_loss: 0.2580 - learning_rate: 2.5000e-04

# %%
y_pred = model.predict(X_test)
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('LSTM - TSLA Close Price Prediction')
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Shifts predicted and actual values to align visually
y_pred_adj = y_pred_inv[1:]

y_test_adj = y_test_inv[:-1]

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_adj, label='Actual', color='steelblue', linewidth=2)
plt.plot(y_pred_adj, label='Predicted (Shifted)', color='orange', linestyle='--', linewidth=2)
plt.title('LSTM Prediction vs Actual (Aligned)', fontsize=14)
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(range(1, len(y_pred_adj)+1), y_pred_adj, label='Predicted')
plt.plot(range(1, len(y_test_adj)+1), y_test_adj, label='Actual')

# %%
print("Scaled y_pred range:", y_pred.min(), y_pred.max())
print("Unscaled y_pred range:", y_pred_inv.min(), y_pred_inv.max())
# Out:
# Scaled y_pred range: -0.17761418 0.0328846
# Unscaled y_pred range: 291.8651 312.97638

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Training samples:", X_train.shape[0])
# Out:
# Training samples: 188

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# metrics
mae = mean_absolute_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
r2 = r2_score(y_test_inv, y_pred_inv)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.2f}")
# Out:
# MAE: 25.87
# RMSE: 31.87
# R²: -0.70

# %% [markdown]
# #EDA-TWEETS

# %%
Text = elon_df['Tweets'].to_numpy()

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# **clean tweet:**

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def clean_tweet(text):
    if pd.isnull(text):
        return " "
    text = text.lower()                           # Converting to lowercase
    text = re.sub(r"http\S+|https\S+", "", text)  # Removing URLs, mentions, hashtags
    text = re.sub(r"@\w+|#\w+", "", text)         # Remove @mentions and #hashtags using regex
    text = re.sub(r"[^a-zA-Z\s]", "", text)       # Remove any characters that are not letters
    text = re.sub(r"\s+", " ", text).strip()      # Replace multiple spaces
    words = word_tokenize(text)
    words = [lemmatizer.lemmatize(word) for word in words if word.lower() not in stop_words]
    return " ".join(words)

# %% [markdown]
# Apply the clean_tweet() function to every row in the 'Tweets' column:

# %%
text_cleaned = [clean_tweet(text) for text in Text]

# %%
#Tokenizer
tokenizer = Tokenizer(oov_token='<OOV>')
tokenizer.fit_on_texts(text_cleaned)
word_index = tokenizer.word_index
seqs = tokenizer.texts_to_sequences(text_cleaned)
padded = pad_sequences(seqs, padding='post')

# %%
elon_df['Processed_Tweet'] = elon_df['Tweets'].apply(clean_tweet)

# %%
#Group tweets by date
daily_tweets = elon_df.groupby('Date')['Processed_Tweet'].apply(lambda x: ' '.join(x)).reset_index()

# %%
daily_tweets
# Out:
#                           Date  \
# 0    2021-09-01 02:44:40+00:00
# 1    2021-09-01 16:13:33+00:00
# 2    2021-09-01 16:21:41+00:00
# 3    2021-09-01 16:42:32+00:00
# 4    2021-09-01 16:46:52+00:00
# ...                        ...
# 3657 2022-08-30 22:52:58+00:00
# 3658 2022-08-31 15:06:53+00:00
# 3659 2022-08-31 15:13:23+00:00
# 3660 2022-08-31 15:16:57+00:00
# 3661 2022-08-31 15:39:27+00:00
#
#                                         Processed_Tweet
# 0                                                   yup
# 1     consider spending money actual lunar lander ha...
# 2      filing legal action spacex actually fulltime job
# 3     satellite launching next month intersatellite ...
# 4     technically data packet need touch regular int...
# ...                                                 ...
# 3657                               go k owner next week
# 3658                                launching every day
# 3659                       yeah aiming flight next year
# 3660
# 3661                               intend soon possible
#
# [3662 rows x 2 columns]

# %%
# Combine all cleaned tweets into one text
all_words = ' '.join(daily_tweets['Processed_Tweet']).split()
#Counts how many times each word appears
word_freq = Counter(all_words)
#Gets the 20 most frequent words
common_words = word_freq.most_common(20)

# %%
# הצגת מילים
words, counts = zip(*common_words)
plt.figure(figsize=(12,5))
sns.barplot(x=list(words), y=list(counts))
plt.title("Top 20 Most Common Words")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #merge tabels

# %%
daily_tweets['Date'] = pd.to_datetime(daily_tweets['Date'])

# %%
tsla.index = pd.to_datetime(tsla.index)

# %%
elon_df['Date'] = elon_df['Date'].dt.date

# %%
tsla.index = pd.to_datetime(tsla.index).date
tsla_df = tsla.reset_index().rename(columns={"index": "Date"})
daily_tweets['Date'] = pd.to_datetime(daily_tweets['Date']).dt.date

# %%
# Merge tsla and daily_tweets using date as the key
df_merged = pd.merge(tsla,daily_tweets, left_index=True, right_on='Date', how='left')

# %%
df_merged
# Out:
#              Close        High         Low        Open    Volume    Change  \
# 0.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 1.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 2.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 3.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 4.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# ...            ...         ...         ...         ...       ...       ...
# 3653.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3654.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3655.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3656.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3657.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
#
#         label        Date                                    Processed_Tweet
# 0.0       0.0  2021-09-01                                                yup
# 1.0       0.0  2021-09-01  consider spending money actual lunar lander ha...
# 2.0       0.0  2021-09-01   filing legal action spacex actually fulltime job
# 3.0       0.0  2021-09-01  satellite launching next month intersatellite ...
# 4.0       0.0  2021-09-01  technically data packet need touch regular int...
# ...       ...         ...                                                ...
# 3653.0    0.0  2022-08-30  kickass internet connection coming royal carib...
# 3654.0    0.0  2022-08-30  even better reduced latency amp jitter hardwar...
# 3655.0    0.0  2022-08-30  spent day walking entire giga berlin productio...
# 3656.0    0.0  2022-08-30                                       sjm question
# 3657.0    0.0  2022-08-30                               go k owner next week
#
# [2563 rows x 9 columns]

# %% [markdown]
# #Tweets Statistic data

# %%
df_filtered = df_merged.copy()

# %%
df_filtered['tweet_length']=df_filtered['Processed_Tweet'].apply(lambda x: len(x) if pd.notnull(x) else 0)

# %%
df_filtered
# Out:
#              Close        High         Low        Open    Volume    Change  \
# 0.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 1.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 2.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 3.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 4.0     244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# ...            ...         ...         ...         ...       ...       ...
# 3653.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3654.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3655.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3656.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
# 3657.0  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
#
#         label        Date                                    Processed_Tweet  \
# 0.0       0.0  2021-09-01                                                yup
# 1.0       0.0  2021-09-01  consider spending money actual lunar lander ha...
# 2.0       0.0  2021-09-01   filing legal action spacex actually fulltime job
# 3.0       0.0  2021-09-01  satellite launching next month intersatellite ...
# 4.0       0.0  2021-09-01  technically data packet need touch regular int...
# ...       ...         ...                                                ...
# 3653.0    0.0  2022-08-30  kickass internet connection coming royal carib...
# 3654.0    0.0  2022-08-30  even better reduced latency amp jitter hardwar...
# 3655.0    0.0  2022-08-30  spent day walking entire giga berlin productio...
# 3656.0    0.0  2022-08-30                                       sjm question
# 3657.0    0.0  2022-08-30                               go k owner next week
#
#         tweet_length
# 0.0                3
# 1.0               75
# 2.0               48
# 3.0              100
# 4.0               99
# ...              ...
# 3653.0            60
# 3654.0           105
# 3655.0            72
# 3656.0            12
# 3657.0            20
#
# [2563 rows x 10 columns]

# %%
df_filtered['tweet_length'].max()
# Out:
# 239

# %%
# Plot histogram of tweet lengths
plt.figure(figsize=(10,5))
sns.histplot(df_filtered['tweet_length'], bins=30, kde=True,color='#8FAADC')
plt.title("Distribution of Tweet Lengths (in characters)", fontsize=14)
plt.xlabel("Tweet Length (characters)")
plt.ylabel("Number of Tweets")
plt.show()

# %%
df_filtered['Date Created'] = pd.to_datetime(df_filtered['Date'])
df_filtered['month'] = df_filtered['Date Created'].dt.to_period('M')

monthly_counts = df_filtered.groupby('month').size()

# Plot monthly tweet counts
monthly_counts.plot(kind='bar', figsize=(14,5), color='#8FAADC')
plt.title("Number of Tweets per Month", fontsize=14)
plt.ylabel("Tweet Count")
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Count the number of tweets per day
tweets_per_day = df_filtered['Date Created'].dt.date.value_counts().sort_index()

# Plot histogram of tweet frequency per day
plt.figure(figsize=(10,5))
sns.histplot(tweets_per_day, bins=30, kde=True, color='#2F5597')
plt.title("Distribution of Tweet Counts Per Day", fontsize=14)
plt.xlabel("Number of Tweets per Day")
plt.ylabel("Number of Days")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Count tweets per day
tweets_per_day = df_filtered['Date Created'].dt.date.value_counts().sort_index()

# Display basic statistics
print("Tweet Frequency Per Day Statistics:")
print(f" Mean: {tweets_per_day.mean():.2f}")
print(f" Median: {tweets_per_day.median()}")
print(f" Max: {tweets_per_day.max()}")
print(f" Min: {tweets_per_day.min()}")
print(f" Std Dev: {tweets_per_day.std():.2f}")
# Out:
# Tweet Frequency Per Day Statistics:
#  Mean: 10.21
#  Median: 9.0
#  Max: 41
#  Min: 1
#  Std Dev: 7.75

# %% [markdown]
# #SENTIMENT - tweets

# %%
df_filtered_copy=df_filtered[['Close','Date','Processed_Tweet','tweet_length']]

# %%
df_filtered_copy
# Out:
#              Close        Date  \
# 0.0     244.696671  2021-09-01
# 1.0     244.696671  2021-09-01
# 2.0     244.696671  2021-09-01
# 3.0     244.696671  2021-09-01
# 4.0     244.696671  2021-09-01
# ...            ...         ...
# 3653.0  277.700012  2022-08-30
# 3654.0  277.700012  2022-08-30
# 3655.0  277.700012  2022-08-30
# 3656.0  277.700012  2022-08-30
# 3657.0  277.700012  2022-08-30
#
#                                           Processed_Tweet  tweet_length
# 0.0                                                   yup             3
# 1.0     consider spending money actual lunar lander ha...            75
# 2.0      filing legal action spacex actually fulltime job            48
# 3.0     satellite launching next month intersatellite ...           100
# 4.0     technically data packet need touch regular int...            99
# ...                                                   ...           ...
# 3653.0  kickass internet connection coming royal carib...            60
# 3654.0  even better reduced latency amp jitter hardwar...           105
# 3655.0  spent day walking entire giga berlin productio...            72
# 3656.0                                       sjm question            12
# 3657.0                               go k owner next week            20
#
# [2563 rows x 4 columns]

# %%
df_filtered_copy.isna().sum()
# Out:
# Close               0
# Date                0
# Processed_Tweet    17
# tweet_length        0
# dtype: int64

# %%
df_filtered_copy=df_filtered_copy.dropna()

# %%
df_filtered_copy.isna().sum()
# Out:
# Close              0
# Date               0
# Processed_Tweet    0
# tweet_length       0
# dtype: int64

# %%
len(padded[1])
# Out:
# 35

# %%
list(word_index.items())[:3]
# Out:
# [('<OOV>', 1), ('amp', 2), ('tesla', 3)]

# %%
MAXLEN = len(padded[1])

# %%
X = padded
y = np.expand_dims(X, axis=-1)

# %%
model = Sequential([
    Embedding(input_dim=len(word_index) + 1, output_dim=64),
    SimpleRNN(16),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    #Dense(1, activation='sigmoid')  #BINARY
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# SENTIMENT
sentiment_scores = model.predict(padded).flatten()
df_filtered_copy['sentiment_score'] = sentiment_scores
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-5e345db0044f> in <cell line: 0>()
#      13 # SENTIMENT
#      14 sentiment_scores = model.predict(padded).flatten()
# ---> 15 df_filtered_copy['sentiment_score'] = sentiment_scores
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
#    5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (3662) does not match length of index (2563)

# %%
#model
model = Sequential([
    Embedding(input_dim=len(word_index) + 1, output_dim=64),
    GlobalAveragePooling1D(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    #Dense(1, activation='sigmoid')  #BINARY
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# SENTIMENT
sentiment_scores = model.predict(padded).flatten()
elon_df['sentiment_score'] = sentiment_scores
# Out:
# WARNING:tensorflow:5 out of the last 118 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c70c696e200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
elon_df
# Out:
#                    Date Created  \
# 80    2022-08-31 15:39:27+00:00
# 81    2022-08-31 15:16:57+00:00
# 82    2022-08-31 15:13:23+00:00
# 83    2022-08-31 15:06:53+00:00
# 84    2022-08-30 22:52:58+00:00
# ...                         ...
# 3737  2021-09-01 16:46:52+00:00
# 3738  2021-09-01 16:42:32+00:00
# 3739  2021-09-01 16:21:41+00:00
# 3740  2021-09-01 16:13:33+00:00
# 3741  2021-09-01 02:44:40+00:00
#
#                                                  Tweets        Date  \
# 80    @ChrisZheng001 I intend to do so as soon as po...  2022-08-31
# 81                                     @teslaownersSV 🤣  2022-08-31
# 82    @SciGuySpace Yeah, aiming for up to 100 flight...  2022-08-31
# 83                          Now launching every ~5 days  2022-08-31
# 84    @WholeMarsBlog @jonbbc @aelluswamy 10.69.2 goe...  2022-08-30
# ...                                                 ...         ...
# 3737  @DJSnM @thesheetztweetz @johnkrausphotos @Lyla...  2021-09-01
# 3738  @DJSnM @thesheetztweetz @johnkrausphotos @Lyla...  2021-09-01
# 3739  @thesheetztweetz Filing legal actions against ...  2021-09-01
# 3740  @SciGuySpace He should consider spending some ...  2021-09-01
# 3741    @MarcusHouse @BocaChicaGal @NASASpaceflight Yup  2021-09-01
#
#                                           Cleaned_Tweet  \
# 80                   chriszheng001 intend soon possible
# 81                                        teslaownerssv
# 82         sciguyspace yeah aiming 100 flight next year
# 83                                  launching every day
# 84    wholemarsblog jonbbc aelluswamy 10.69.2 go 100...
# ...                                                 ...
# 3737  djsnm thesheetztweetz johnkrausphotos lylakohi...
# 3738  djsnm thesheetztweetz johnkrausphotos lylakohi...
# 3739  thesheetztweetz filing legal action spacex act...
# 3740  sciguyspace consider spending money actual lun...
# 3741       marcushouse bocachicagal nasaspaceflight yup
#
#                                         Processed_Tweet  sentiment_score
# 80    amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 81    amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 82    amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 83    amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 84    amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# ...                                                 ...              ...
# 3737  amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 3738  amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 3739  amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 3740  amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
# 3741  amp tesla wholemarsblog billym2k teslaownerssv...         0.001899
#
# [3662 rows x 6 columns]

# %%
daily_sentiment = elon_df.groupby("Date")["sentiment_score"].median().reset_index()

# %%
daily_sentiment
# Out:
#            Date  sentiment_score
# 0    2021-09-01         0.001899
# 1    2021-09-02         0.001899
# 2    2021-09-03         0.001899
# 3    2021-09-04         0.001899
# 4    2021-09-06         0.001899
# ..          ...              ...
# 333  2022-08-27         0.001899
# 334  2022-08-28         0.001899
# 335  2022-08-29         0.001899
# 336  2022-08-30         0.001899
# 337  2022-08-31         0.001899
#
# [338 rows x 2 columns]

# %%
# Merge
df_merged["Date"] = pd.to_datetime(df_merged["Date"])
daily_sentiment["Date"] = pd.to_datetime(daily_sentiment["Date"])


df_merged = df_merged.merge(daily_sentiment, on="Date", how="left")

#Fills missing days (no tweets) with neutral score 0.5
df_merged["sentiment_score"].fillna(0.5, inplace=True)
# Out:
# <ipython-input-342-477812697ea8>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_merged["sentiment_score"].fillna(0.5, inplace=True)

# %%
df_merged
# Out:
#           Close        High         Low        Open    Volume    Change  \
# 0    244.696671  247.330002  243.756668  244.693329  39612900 -0.566666
# 1    244.130005  246.990005  243.513336  244.833328  38331900  0.393326
# 2    244.523331  244.666672  241.399994  244.083328  45738300  6.449997
# 3    250.973328  253.399994  246.419998  246.666672  60119400  0.316666
# 4    251.289993  254.816666  246.923340  253.860001  56379000  0.330002
# ..          ...         ...         ...         ...       ...       ...
# 246  297.096680  303.646667  296.500000  297.563324  57259800 -1.026672
# 247  296.070007  302.959991  291.600006  302.359985  53230000 -7.980011
# 248  288.089996  302.000000  287.470001  297.429993  57163900 -3.269989
# 249  284.820007  287.739990  280.700012  282.829987  41864700 -7.119995
# 250  277.700012  288.480011  272.649994  287.869995  50541800 -2.090027
#
#      label       Date                                      Cleaned_Tweet  \
# 0      0.0 2021-09-01  samtwits archillect archillect kristennetten s...
# 1      1.0 2021-09-02  leastimalive archillect fkn tryin teslaaibot e...
# 2      1.0 2021-09-03  flcnhvy wholemarsblog truth_tesla limitingthe ...
# 3      1.0 2021-09-07  rogozin thanks favorite tea saycheesedgtl work...
# 4      1.0 2021-09-08                    ppathole sum well wholemarsblog
# ..     ...        ...                                                ...
# 246    0.0 2022-08-24  bbc_future would gladly obey command tell sayi...
# 247    0.0 2022-08-25  livestream big news hour teslaownerssv 10.69.1...
# 248    0.0 2022-08-26  skmorefield indeed sadly anti-human country in...
# 249    0.0 2022-08-29  teslaownerssv grow least meter time wholemarsb...
# 250    0.0 2022-08-30  wholemarsblog jonbbc aelluswamy 10.69.2 go 100...
#
#      sentiment_score
# 0           0.001899
# 1           0.001899
# 2           0.001899
# 3           0.001899
# 4           0.001899
# ..               ...
# 246         0.001899
# 247         0.001899
# 248         0.001899
# 249         0.001899
# 250         0.001899
#
# [251 rows x 10 columns]

# %%
plt.figure(figsize=(14, 6))
plt.plot(df_merged['Date'], df_merged['sentiment_score'], color='orange', label='Daily Sentiment')
plt.axhline(0.5, color='gray', linestyle='--', label='Neutral Sentiment (0.5)')
plt.title('Daily Tweet Sentiment Over Time', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Sentiment Score')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Classic Models With Sentiment

# %%
scale_features = ['Close','High','Low','Open','Volume']
no_scale_features = ["sentiment_score"]
features_with_sent = scale_features + no_scale_features

# %%
split_index = int(len(df_merged) * 0.8)
train = df_merged.iloc[:split_index]
test = df_merged.iloc[split_index:]

X_train = train[features_with_sent]
X_test = test[features_with_sent]
y_train = train['label']
y_test = test['label']

# %%
scaler = StandardScaler()
X_train_scaled_part = scaler.fit_transform(X_train[scale_features])
X_test_scaled_part = scaler.transform(X_test[scale_features])

# %%
# שלב 1 – שילוב הסקיילינג עם sentiment_score
X_train_scaled = np.hstack([X_train_scaled_part, X_train[no_scale_features].values])
X_test_scaled = np.hstack([X_test_scaled_part, X_test[no_scale_features].values])

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=features_with_sent, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=features_with_sent, index=X_test.index)

# %% [markdown]
# same classic models codes

# %%
df_merged[["Close", "High", "Low", "Open", "Volume", "sentiment_score"]].isna().sum()
# Out:
# Close              0
# High               0
# Low                0
# Open               0
# Volume             0
# sentiment_score    0
# dtype: int64

# %%
np.isnan(X_train_scaled).sum()
# Out:
# Close              0
# High               0
# Low                0
# Open               0
# Volume             0
# sentiment_score    0
# dtype: int64

# %%
#Defining models
models = {

    "Logistic Regression": LogisticRegression(max_iter=50, C=0.001, random_state=42,class_weight='balanced'),
    "Random Forest": RandomForestClassifier(n_estimators=200, max_depth=7, min_samples_leaf=5, random_state=42),
    "Decision Tree": DecisionTreeClassifier(max_depth=6, min_samples_leaf=5, random_state=42),
    "SVM": SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=42),
    "KNN": KNeighborsClassifier(n_neighbors=7),
    "XGBoost": XGBClassifier(n_estimators=100, max_depth=4, learning_rate=0.1, use_label_encoder=False, eval_metric='logloss', random_state=42)
}

# %%
print(tsla['label'].value_counts(normalize=True))
# Out:
# label
# 1.0    0.541833
# 0.0    0.458167
# Name: proportion, dtype: float64

# %%
# Initialize results list
results = []

# Loop over models
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    conf = confusion_matrix(y_test, y_pred)

    # Append to results list
    results.append({
        "Model": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1-score": f1,
        "Confusion Matrix": conf
    })
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [23:50:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
results_df = pd.DataFrame(results).drop(columns=['Confusion Matrix'])
results_df.sort_values(by='F1-score', ascending=False)
# Out:
#                  Model  Accuracy  Precision    Recall  F1-score
# 1        Random Forest  0.568627   0.553191  0.962963  0.702703
# 3                  SVM  0.529412   0.529412  1.000000  0.692308
# 0  Logistic Regression  0.549020   0.543478  0.925926  0.684932
# 5              XGBoost  0.588235   0.583333  0.777778  0.666667
# 4                  KNN  0.549020   0.576923  0.555556  0.566038
# 2        Decision Tree  0.392157   0.333333  0.148148  0.205128

# %%
for result in results:
    plt.figure(figsize=(4,3))
    sns.heatmap(result['Confusion Matrix'], annot=True, fmt='d', cmap='Blues')
    plt.title(f"Confusion Matrix - {result['Model']}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=results_df, x='Model', y='F1-score')
plt.title('F1-score Comparison Between Models')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #LSTM With Sentiment

# %%
features_df = df_merged[["Close", "sentiment_score"]].copy()
features_df = features_df.dropna()

# %%
split_index = int(len(features_df) * 0.8)

train_df = features_df.iloc[:split_index]
test_df = features_df.iloc[split_index:]

# %%
scaler_close = MinMaxScaler(feature_range=(-1, 1))
scaler_sentiment = MinMaxScaler(feature_range=(-1, 1))

train_scaled = np.hstack([
    scaler_close.fit_transform(train_df[["Close"]]),
    scaler_sentiment.fit_transform(train_df[["sentiment_score"]])
])

test_scaled = np.hstack([
    scaler_close.transform(test_df[["Close"]]),
    scaler_sentiment.transform(test_df[["sentiment_score"]])
])

# %%
def create_multifeature_sequences(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i + window_size][0])  # רק מחיר הסגירה כיעד
    return np.array(X), np.array(y)

window_size = 12
X_train, y_train = create_multifeature_sequences(train_scaled, window_size)
X_test, y_test = create_multifeature_sequences(test_scaled, window_size)

# %%
print(X_train.shape)
# Out:
# (188, 12, 2)

# %%
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(window_size, X_train.shape[2])),
    BatchNormalization(),
    Dropout(0.3),
    LSTM(64),
    Dropout(0.3),
    Dense(1)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# #LSTM

# %%
model.compile(loss="mse", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# %%
history = model.fit(
    X_train,y_train,
    validation_data=(X_test,y_test),
    epochs=100,
    batch_size=16,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.1799 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1367 - val_loss: 0.1346 - learning_rate: 0.0010
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1100 - val_loss: 0.1438 - learning_rate: 0.0010
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0705 - val_loss: 0.1292 - learning_rate: 0.0010
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0604 - val_loss: 0.1180 - learning_rate: 0.0010
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0700 - val_loss: 0.1292 - learning_rate: 0.0010
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0689 - val_loss: 0.1136 - learning_rate: 5.0000e-04
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0543 - val_loss: 0.1238 - learning_rate: 5.0000e-04
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0545 - val_loss: 0.1095 - learning_rate: 5.0000e-04
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0585 - val_loss: 0.1145 - learning_rate: 5.0000e-04
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0431 - val_loss: 0.1161 - learning_rate: 5.0000e-04
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0403 - val_loss: 0.1062 - learning_rate: 5.0000e-04
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0393 - val_loss: 0.1015 - learning_rate: 5.0000e-04
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0350 - val_loss: 0.0977 - learning_rate: 5.0000e-04
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0379 - val_loss: 0.1030 - learning_rate: 5.0000e-04
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0442 - val_loss: 0.0957 - learning_rate: 5.0000e-04
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0434 - val_loss: 0.0946 - learning_rate: 5.0000e-04
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0410 - val_loss: 0.0898 - learning_rate: 5.0000e-04
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0447 - val_loss: 0.0883 - learning_rate: 5.0000e-04
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0393 - val_loss: 0.0787 - learning_rate: 5.0000e-04
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0390 - val_loss: 0.0708 - learning_rate: 5.0000e-04
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0391 - val_loss: 0.0710 - learning_rate: 5.0000e-04
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0428 - val_loss: 0.0670 - learning_rate: 5.0000e-04
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0432 - val_loss: 0.0753 - learning_rate: 5.0000e-04
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0463 - val_loss: 0.0828 - learning_rate: 5.0000e-04
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0425 - val_loss: 0.0630 - learning_rate: 5.0000e-04
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0328 - val_loss: 0.0756 - learning_rate: 5.0000e-04
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0446 - val_loss: 0.0791 - learning_rate: 5.0000e-04
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0349 - val_loss: 0.0653 - learning_rate: 5.0000e-04
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0308 - val_loss: 0.0544 - learning_rate: 5.0000e-04
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0407 - val_loss: 0.0628 - learning_rate: 5.0000e-04
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0427 - val_loss: 0.0780 - learning_rate: 5.0000e-04
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0406 - val_loss: 0.0626 - learning_rate: 5.0000e-04
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0410 - val_loss: 0.0645 - learning_rate: 5.0000e-04
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0542 - val_loss: 0.0547 - learning_rate: 5.0000e-04
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0250 - val_loss: 0.0555 - learning_rate: 2.5000e-04
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0320 - val_loss: 0.0614 - learning_rate: 2.5000e-04
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0363 - val_loss: 0.0825 - learning_rate: 2.5000e-04
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0268 - val_loss: 0.0710 - learning_rate: 2.5000e-04
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0324 - val_loss: 0.0725 - learning_rate: 2.5000e-04

# %%
y_pred = model.predict(X_test)
y_pred_inv = scaler_close.inverse_transform(y_pred)
y_test_inv = scaler_close.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label='Actual')
plt.plot(y_pred_inv, label='Predicted')
plt.title('LSTM - TSLA Close Price Prediction')
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# נחתוך את התחזית - נוריד את הערך האחרון (כי אין לו ערך אמת תואם)
y_pred_adj = y_pred_inv[1:]

# נחתוך גם את האמת - נוריד את הערך הראשון (כי לא הייתה תחזית עבורו)
y_test_adj = y_test_inv[:-1]

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_adj, label='Actual', color='steelblue', linewidth=2)
plt.plot(y_pred_adj, label='Predicted (Shifted)', color='orange', linestyle='--', linewidth=2)
plt.title('LSTM Prediction vs Actual (Aligned)', fontsize=14)
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(range(1, len(y_pred_adj)+1), y_pred_adj, label='Predicted')
plt.plot(range(1, len(y_test_adj)+1), y_test_adj, label='Actual')

# %%
print("Scaled y_pred range:", y_pred.min(), y_pred.max())
print("Unscaled y_pred range:", y_pred_inv.min(), y_pred_inv.max())
# Out:
# Scaled y_pred range: -0.423425 0.015775727
# Unscaled y_pred range: 267.21234 311.2605

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Training samples:", X_train.shape[0])
# Out:
# Training samples: 188

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# מדדים
mae = mean_absolute_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
r2 = r2_score(y_test_inv, y_pred_inv)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.2f}")
# Out:
# MAE: 18.37
# RMSE: 27.00
# R²: -0.22
